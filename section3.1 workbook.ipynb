# %%
print ("Hello world")
# Out:
# Hello world

# %% [markdown]
# 1. Python lang: Interpreted lsanguage/ highh level lang like natural lang
# 2. Natural lang: is one of 2 classes. is spoken language that forms on own, think SLANG
# 3. Algorithms: series of steps to solve a problem.
# 4. Program used to write python: IDE & CDI
# 5. Pythion file ext: .PY
# 6. Area add commands: Terminal
# 7. #1 Rule: Complexity is the enemy of efficiancy

# %% [markdown]
# # Section 3.1 Workbook
